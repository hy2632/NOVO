# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/jordantanudjaja/Downloads'

# %%
#data = pd.read_excel('TRACT_ZIP_122019.xlsx')
#data = pd.read_excel('TRACT_ZIP_122018.xlsx')
data = pd.read_excel('TRACT_ZIP_122017.xlsx')

# %%
data
# Out:
#               tract    zip  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0        1001020100  36067   1.000000   1.000000       1.00   1.000000
# 1        1001020200  36008   0.028243   0.012987       0.00   0.023846
# 2        1001020200  36067   0.971757   0.987013       1.00   0.976154
# 3        1001020300  36067   1.000000   1.000000       1.00   1.000000
# 4        1001020400  36067   0.025543   0.585987       0.25   0.071038
# ...             ...    ...        ...        ...        ...        ...
# 168657  78030960800    802   1.000000   1.000000       1.00   1.000000
# 168658  78030960900    802   1.000000   1.000000       1.00   1.000000
# 168659  78030961000    802   1.000000   1.000000       1.00   1.000000
# 168660  78030961100    802   1.000000   1.000000       1.00   1.000000
# 168661  78030961200    802   1.000000   1.000000       1.00   1.000000
#
# [168662 rows x 6 columns]

# %%
#data = data.drop(['tract.1'], axis=1)
#data = data.drop(['tract'], axis=1)

# %%
data['Zips'] = "Zip_" + (data.groupby("tract").cumcount() + 1).astype(str)
data = data.pivot(index="tract", values="zip", columns="Zips")

# %%
data[data['Zip_1'] > 0]
# Out:
# Zips           Zip_1  Zip_10  Zip_11  Zip_12  Zip_13  Zip_14  Zip_15  Zip_16  \
# tract
# 1001020100   36067.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001020200   36008.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001020300   36067.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001020400   36067.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1001020500   36066.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# 78030960800    802.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 78030960900    802.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 78030961000    802.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 78030961100    802.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 78030961200    802.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
dir(data)
# Out:
# ['T',
#  'Zip_1',
#  'Zip_10',
#  'Zip_11',
#  'Zip_12',
#  'Zip_13',
#  'Zip_14',
#  'Zip_15',
#  'Zip_16',
#  'Zip_17',
#  'Zip_18',
#  'Zip_19',
#  'Zip_2',
#  'Zip_20',
#  'Zip_21',
#  'Zip_22',
#  'Zip_23',
#  'Zip_24',
#  'Zip_25',
#  'Zip_26',
#  'Zip_27',
#  'Zip_28',
#  'Zip_29',
#  'Zip_3',
#  'Zip_30',
#  'Zip_31',
#  'Zip_32',
#  'Zip_33',
#  'Zip_34',
#  'Zip_35',
#  'Zip_36',
#  'Zip_37',
#  'Zip_38',
#  'Zip_39',
#  'Zip_4',
#  'Zip_40',
#  'Zip_41',
#  'Zip_42',
#  'Zip_43',
#  'Zip_44',
#  'Zip_45',
#  'Zip_46',
#  'Zip_47',
#  'Zip_48',
#  'Zip_5',
#  'Zip_6',
#  'Zip_7',
#  'Zip_8',
#  'Zip_9',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
# ...

# %%
data.to_excel('12_2017_Tract_zip_dictionary.xlsx')
