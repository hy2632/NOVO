# %%
import pandas as pd
import os
import numpy as np

# %%
os.path
# Out:
# <module 'ntpath' from 'C:\\Anaconda3\\lib\\ntpath.py'>

# %%
dict_2018 = pd.read_excel('Data/ZIP_TRACT_122018.xlsx')

# %%
dict_2018
# Out:
#           zip        tract  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0         601  72001956700   0.671739   0.411079   0.530973   0.654116
# 1         603  72005401302   0.082247   0.036098   0.072491   0.079523
# 2         623  72023830400   0.331718   0.551763   0.479730   0.344927
# 3         638  72039955700   0.436658   0.819444   0.777778   0.455135
# 4         646  72051540100   0.142668   0.342226   0.148515   0.156662
# ...       ...          ...        ...        ...        ...        ...
# 171496  77327  48291700700   0.000075   0.000000   0.000000   0.000070
# 171497  79853  48141010506   1.000000   0.000000   0.000000   0.714286
# 171498  11040  36059302300   0.000000   0.000692   0.000000   0.000063
# 171499  15205  42003562600   0.000082   0.000000   0.000000   0.000069
# 171500  98447  53053071504   0.000000   1.000000   0.000000   1.000000
#
# [171501 rows x 6 columns]

# %%
d2018 = dict_2018[['tract', 'zip']]

# %%
d2018
# Out:
#               tract    zip
# 0       72001956700    601
# 1       72005401302    603
# 2       72023830400    623
# 3       72039955700    638
# 4       72051540100    646
# ...             ...    ...
# 171496  48291700700  77327
# 171497  48141010506  79853
# 171498  36059302300  11040
# 171499  42003562600  15205
# 171500  53053071504  98447
#
# [171501 rows x 2 columns]

# %% [markdown]
# ## Combine Age Data into one spreadsheet

# %%
age2534 = pd.read_excel('Data given by Lisa/Census Tract Level/Age/Estimated age 25 to 34.xlsx',sheet_name='Age 25 to 34')
age3544 = pd.read_excel('Data given by Lisa/Census Tract Level/Age/Estimated age 35-44.xlsx',sheet_name='Age 35 to 44')
age4554 = pd.read_excel('Data given by Lisa/Census Tract Level/Age/Estimated age 45 to 54.xlsx',sheet_name='Age 45 to 54')
age5564 = pd.read_excel('Data given by Lisa/Census Tract Level/Age/Estimated age 55 to 64.xlsx',sheet_name='Age 55 to 64')
age65 = pd.read_excel('Data given by Lisa/Census Tract Level/Age/Estimated age 65 or older.xlsx', sheet_name='People age 65 or older')
agemed = pd.read_excel('Data given by Lisa/Census Tract Level/Age/Median Age.xlsx', sheet_name = 'Median Age')

# %%
age2534 = age2534.drop(index=range(74134,74145))
age3544 = age3544.drop(index=range(74134,74145))
age4554 = age4554.drop(index=range(74134,74145))
age5564 = age5564.drop(index=range(74134,74145))
age65 = age65.drop(index=range(74134,74145))
agemed = agemed.drop(index=range(74134,74145))

# %%
def merger(*args):
    new = args[0]
    for i in range(len(args)-1):
        new = pd.merge(new,args[i+1],how = 'inner')
    return new
age = merger(age2534,age3544,age4554,age5564,age65,agemed)

# %%
age
# Out:
#       Census Tract State     FIPS Code  Formatted FIPS  \
# 0      01001020100    AL  1.001020e+09    1.001020e+09
# 1      01001020200    AL  1.001020e+09    1.001020e+09
# 2      01001020300    AL  1.001020e+09    1.001020e+09
# 3      01001020400    AL  1.001020e+09    1.001020e+09
# 4      01001020500    AL  1.001020e+09    1.001020e+09
# ...            ...   ...           ...             ...
# 74129  78030960900    VI  7.803096e+10    7.803096e+10
# 74130  78030961000    VI  7.803096e+10    7.803096e+10
# 74131  78030961100    VI  7.803096e+10    7.803096e+10
# 74132  78030961200    VI  7.803096e+10    7.803096e+10
# 74133  78030990000    VI  7.803099e+10    7.803099e+10
#
#        Estimated percent of all people age 25-34, between 2014-2018.  \
# 0                                                  10.04
# 1                                                  14.30
# 2                                                  20.43
# 3                                                  10.86
# 4                                                  15.62
# ...                                                  ...
# 74129                                                NaN
# 74130                                                NaN
# 74131                                                NaN
# 74132                                                NaN
# 74133                                                NaN
#
#        Estimated percent of all people age 35-44, between 2014-2018.  \
# 0                                                  12.32
# 1                                                  14.64
# 2                                                  10.67
# 3                                                   9.81
# 4                                                  14.43
# ...                                                  ...
# 74129                                                NaN
# 74130                                                NaN
# 74131                                                NaN
# 74132                                                NaN
# 74133                                                NaN
#
#        Estimated percent of all people age 45-54, between 2014-2018.  \
# 0                                                  16.59
# 1                                                  17.31
# 2                                                  11.13
# 3                                                  14.80
# 4                                                  13.95
# ...                                                  ...
# 74129                                                NaN
# 74130                                                NaN
# 74131                                                NaN
# 74132                                                NaN
# 74133                                                NaN
#
#        Estimated percent of all people age 55-64, between 2014-2018.  \
# 0                                                  16.07
# 1                                                  10.90
# 2                                                  10.30
# 3                                                  13.29
# 4                                                  10.71
# ...                                                  ...
# 74129                                                NaN
# 74130                                                NaN
# 74131                                                NaN
# 74132                                                NaN
# 74133                                                NaN
#
#        Estimated percent of all people 65 or older, between 2014-2018.  \
# 0                                                  12.74
# 1                                                  14.00
# 2                                                  16.69
# 3                                                  23.52
# 4                                                  13.82
# ...                                                  ...
# 74129                                                NaN
# 74130                                                NaN
# 74131                                                NaN
# 74132                                                NaN
# 74133                                                NaN
#
#        Estimated typical (median) age of all people between 2013-2017.
# 0                                                   40.0
# 1                                                   39.0
# 2                                                   37.0
# 3                                                   43.0
# 4                                                   37.0
# ...                                                  ...
# 74129                                                NaN
# 74130                                                NaN
# 74131                                                NaN
# 74132                                                NaN
# 74133                                                NaN
#
# [74134 rows x 10 columns]

# %% [markdown]
# ## We can use Census Tract as Index

# %%
age['Census Tract'].is_unique
# Out:
# True

# %%
age = age.set_index('Census Tract')

# %% [markdown]
# ## Change data type(object to int)

# %%
age.index = age.index.astype('int64')

# %%
age.dtypes
# Out:
# State                                                               object
# FIPS Code                                                          float64
# Formatted FIPS                                                     float64
# Estimated percent of all people age 25-34, between 2014-2018.      float64
# Estimated percent of all people age 35-44, between 2014-2018.      float64
# Estimated percent of all people age 45-54, between 2014-2018.      float64
# Estimated percent of all people age 55-64, between 2014-2018.      float64
# Estimated percent of all people 65 or older, between 2014-2018.    float64
# Estimated typical (median) age of all people between 2013-2017.    float64
# dtype: object

# %%
age = age.sort_index()

# %%
age
# Out:
#              State     FIPS Code  Formatted FIPS  \
# Census Tract
# 1001020100      AL  1.001020e+09    1.001020e+09
# 1001020200      AL  1.001020e+09    1.001020e+09
# 1001020300      AL  1.001020e+09    1.001020e+09
# 1001020400      AL  1.001020e+09    1.001020e+09
# 1001020500      AL  1.001020e+09    1.001020e+09
# ...            ...           ...             ...
# 78030960900     VI  7.803096e+10    7.803096e+10
# 78030961000     VI  7.803096e+10    7.803096e+10
# 78030961100     VI  7.803096e+10    7.803096e+10
# 78030961200     VI  7.803096e+10    7.803096e+10
# 78030990000     VI  7.803099e+10    7.803099e+10
#
#               Estimated percent of all people age 25-34, between 2014-2018.  \
# Census Tract
# 1001020100                                                10.04
# 1001020200                                                14.30
# 1001020300                                                20.43
# 1001020400                                                10.86
# 1001020500                                                15.62
# ...                                                         ...
# 78030960900                                                 NaN
# 78030961000                                                 NaN
# 78030961100                                                 NaN
# 78030961200                                                 NaN
# 78030990000                                                 NaN
#
#               Estimated percent of all people age 35-44, between 2014-2018.  \
# Census Tract
# 1001020100                                                12.32
# 1001020200                                                14.64
# 1001020300                                                10.67
# 1001020400                                                 9.81
# 1001020500                                                14.43
# ...                                                         ...
# 78030960900                                                 NaN
# 78030961000                                                 NaN
# 78030961100                                                 NaN
# 78030961200                                                 NaN
# 78030990000                                                 NaN
#
#               Estimated percent of all people age 45-54, between 2014-2018.  \
# Census Tract
# 1001020100                                                16.59
# 1001020200                                                17.31
# 1001020300                                                11.13
# 1001020400                                                14.80
# 1001020500                                                13.95
# ...                                                         ...
# 78030960900                                                 NaN
# 78030961000                                                 NaN
# 78030961100                                                 NaN
# 78030961200                                                 NaN
# 78030990000                                                 NaN
#
#               Estimated percent of all people age 55-64, between 2014-2018.  \
# Census Tract
# 1001020100                                                16.07
# 1001020200                                                10.90
# 1001020300                                                10.30
# 1001020400                                                13.29
# 1001020500                                                10.71
# ...                                                         ...
# 78030960900                                                 NaN
# 78030961000                                                 NaN
# 78030961100                                                 NaN
# 78030961200                                                 NaN
# 78030990000                                                 NaN
#
#               Estimated percent of all people 65 or older, between 2014-2018.  \
# Census Tract
# 1001020100                                                12.74
# 1001020200                                                14.00
# 1001020300                                                16.69
# 1001020400                                                23.52
# 1001020500                                                13.82
# ...                                                         ...
# 78030960900                                                 NaN
# 78030961000                                                 NaN
# 78030961100                                                 NaN
# 78030961200                                                 NaN
# 78030990000                                                 NaN
#
#               Estimated typical (median) age of all people between 2013-2017.
# Census Tract
# 1001020100                                                 40.0
# 1001020200                                                 39.0
# 1001020300                                                 37.0
# 1001020400                                                 43.0
# 1001020500                                                 37.0
# ...                                                         ...
# 78030960900                                                 NaN
# 78030961000                                                 NaN
# 78030961100                                                 NaN
# 78030961200                                                 NaN
# 78030990000                                                 NaN
#
# [74134 rows x 9 columns]

# %% [markdown]
# ## Just use the newest dict

# %%
d2018['zip'] = d2018['zip'].astype('str')
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d2018['zip']  = d2018['zip'].apply(lambda x:('00'+x)[-5:] if len(x) <= 4 else x)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d2018
# Out:
#               tract    zip
# 0       72001956700  00601
# 1       72005401302  00603
# 2       72023830400  00623
# 3       72039955700  00638
# 4       72051540100  00646
# ...             ...    ...
# 171496  48291700700  77327
# 171497  48141010506  79853
# 171498  36059302300  11040
# 171499  42003562600  15205
# 171500  53053071504  98447
#
# [171501 rows x 2 columns]

# %%
d2018.merge(age, how = 'left', left_on = 'tract', right_on = 'Census Tract')
# Out:
#               tract    zip State     FIPS Code  Formatted FIPS  \
# 0       72001956700  00601    PR  7.200196e+10    7.200196e+10
# 1       72005401302  00603    PR  7.200540e+10    7.200540e+10
# 2       72023830400  00623    PR  7.202383e+10    7.202383e+10
# 3       72039955700  00638    PR  7.203996e+10    7.203996e+10
# 4       72051540100  00646    PR  7.205154e+10    7.205154e+10
# ...             ...    ...   ...           ...             ...
# 171496  48291700700  77327    TX  4.829170e+10    4.829170e+10
# 171497  48141010506  79853    TX  4.814101e+10    4.814101e+10
# 171498  36059302300  11040    NY  3.605930e+10    3.605930e+10
# 171499  42003562600  15205    PA  4.200356e+10    4.200356e+10
# 171500  53053071504  98447    WA  5.305307e+10    5.305307e+10
#
#         Estimated percent of all people age 25-34, between 2014-2018.  \
# 0                                                   11.87
# 1                                                   12.69
# 2                                                   12.81
# 3                                                   13.75
# 4                                                   13.28
# ...                                                   ...
# 171496                                               9.18
# 171497                                              10.41
# 171498                                               7.83
# 171499                                              13.98
# 171500                                              10.46
#
#         Estimated percent of all people age 35-44, between 2014-2018.  \
# 0                                                   13.57
# 1                                                   15.71
# 2                                                    9.44
# 3                                                   10.27
# 4                                                   10.52
# ...                                                   ...
# 171496                                              10.61
# 171497                                              15.08
# 171498                                               8.05
# 171499                                              12.26
# 171500                                              11.02
#
#         Estimated percent of all people age 45-54, between 2014-2018.  \
# 0                                                   11.24
# 1                                                   10.92
# 2                                                   12.16
# 3                                                   10.90
# 4                                                   11.60
# ...                                                   ...
# 171496                                              11.11
# 171497                                              10.84
# 171498                                              14.25
# 171499                                              11.80
# 171500                                              12.34
#
#         Estimated percent of all people age 55-64, between 2014-2018.  \
# 0                                                   11.96
# 1                                                   16.61
# 2                                                   12.60
# 3                                                    6.56
# 4                                                   10.16
# ...                                                   ...
# 171496                                              15.18
# 171497                                              10.99
# 171498                                              16.96
# 171499                                              14.02
# 171500                                               6.77
#
#         Estimated percent of all people 65 or older, between 2014-2018.  \
# 0                                                   15.22
# 1                                                   20.20
# 2                                                   22.20
# 3                                                   17.36
# 4                                                   26.31
# ...                                                   ...
# 171496                                              17.55
# 171497                                               7.79
# 171498                                              23.53
# 171499                                              12.26
# 171500                                               6.06
#
#         Estimated typical (median) age of all people between 2013-2017.
# 0                                                    39.0
# 1                                                    39.0
# 2                                                    35.0
# 3                                                    32.0
# 4                                                    44.0
# ...                                                   ...
# 171496                                               40.0
# 171497                                               26.0
# 171498                                               48.0
# 171499                                               32.0
# 171500                                               23.0
#
# [171501 rows x 11 columns]

# %% [markdown]
# ## Looks like there is some missing data (dict > Age Data)

# %%
d2018.merge(age, how = 'left', left_on = 'tract', right_on = 'Census Tract').dropna()
# Out:
#               tract    zip State     FIPS Code  Formatted FIPS  \
# 0       72001956700  00601    PR  7.200196e+10    7.200196e+10
# 1       72005401302  00603    PR  7.200540e+10    7.200540e+10
# 2       72023830400  00623    PR  7.202383e+10    7.202383e+10
# 3       72039955700  00638    PR  7.203996e+10    7.203996e+10
# 4       72051540100  00646    PR  7.205154e+10    7.205154e+10
# ...             ...    ...   ...           ...             ...
# 171496  48291700700  77327    TX  4.829170e+10    4.829170e+10
# 171497  48141010506  79853    TX  4.814101e+10    4.814101e+10
# 171498  36059302300  11040    NY  3.605930e+10    3.605930e+10
# 171499  42003562600  15205    PA  4.200356e+10    4.200356e+10
# 171500  53053071504  98447    WA  5.305307e+10    5.305307e+10
#
#         Estimated percent of all people age 25-34, between 2014-2018.  \
# 0                                                   11.87
# 1                                                   12.69
# 2                                                   12.81
# 3                                                   13.75
# 4                                                   13.28
# ...                                                   ...
# 171496                                               9.18
# 171497                                              10.41
# 171498                                               7.83
# 171499                                              13.98
# 171500                                              10.46
#
#         Estimated percent of all people age 35-44, between 2014-2018.  \
# 0                                                   13.57
# 1                                                   15.71
# 2                                                    9.44
# 3                                                   10.27
# 4                                                   10.52
# ...                                                   ...
# 171496                                              10.61
# 171497                                              15.08
# 171498                                               8.05
# 171499                                              12.26
# 171500                                              11.02
#
#         Estimated percent of all people age 45-54, between 2014-2018.  \
# 0                                                   11.24
# 1                                                   10.92
# 2                                                   12.16
# 3                                                   10.90
# 4                                                   11.60
# ...                                                   ...
# 171496                                              11.11
# 171497                                              10.84
# 171498                                              14.25
# 171499                                              11.80
# 171500                                              12.34
#
#         Estimated percent of all people age 55-64, between 2014-2018.  \
# 0                                                   11.96
# 1                                                   16.61
# 2                                                   12.60
# 3                                                    6.56
# 4                                                   10.16
# ...                                                   ...
# 171496                                              15.18
# 171497                                              10.99
# 171498                                              16.96
# 171499                                              14.02
# 171500                                               6.77
#
#         Estimated percent of all people 65 or older, between 2014-2018.  \
# 0                                                   15.22
# 1                                                   20.20
# 2                                                   22.20
# 3                                                   17.36
# 4                                                   26.31
# ...                                                   ...
# 171496                                              17.55
# 171497                                               7.79
# 171498                                              23.53
# 171499                                              12.26
# 171500                                               6.06
#
#         Estimated typical (median) age of all people between 2013-2017.
# 0                                                    39.0
# 1                                                    39.0
# 2                                                    35.0
# 3                                                    32.0
# 4                                                    44.0
# ...                                                   ...
# 171496                                               40.0
# 171497                                               26.0
# 171498                                               48.0
# 171499                                               32.0
# 171500                                               23.0
#
# [170781 rows x 11 columns]

# %% [markdown]
# ## Reset index to zipcode

# %%
d2018.merge(age, how = 'left', left_on = 'tract', right_on = 'Census Tract').dropna().set_index('zip').sort_index()
# Out:
#              tract State     FIPS Code  Formatted FIPS  \
# zip
# 00501  36103158607    NY  3.610316e+10    3.610316e+10
# 00601  72001956700    PR  7.200196e+10    7.200196e+10
# 00601  72001956600    PR  7.200196e+10    7.200196e+10
# 00601  72113071700    PR  7.211307e+10    7.211307e+10
# 00602  72003430300    PR  7.200343e+10    7.200343e+10
# ...            ...   ...           ...             ...
# 99925   2198000200    AK  2.198000e+09    2.198000e+09
# 99926   2198940100    AK  2.198940e+09    2.198940e+09
# 99927   2198000100    AK  2.198000e+09    2.198000e+09
# 99928   2130000100    AK  2.130000e+09    2.130000e+09
# 99929   2275000300    AK  2.275000e+09    2.275000e+09
#
#        Estimated percent of all people age 25-34, between 2014-2018.  \
# zip
# 00501                                              14.95
# 00601                                              11.87
# 00601                                              15.24
# 00601                                              14.85
# 00602                                              11.56
# ...                                                  ...
# 99925                                              11.46
# 99926                                              13.70
# 99927                                              11.87
# 99928                                               9.72
# 99929                                              10.59
#
#        Estimated percent of all people age 35-44, between 2014-2018.  \
# zip
# 00501                                              11.62
# 00601                                              13.57
# 00601                                               7.17
# 00601                                              10.97
# 00602                                              11.64
# ...                                                  ...
# 99925                                              11.30
# 99926                                               9.66
# 99927                                              11.95
# 99928                                              12.92
# 99929                                               8.37
#
#        Estimated percent of all people age 45-54, between 2014-2018.  \
# zip
# 00501                                              22.52
# 00601                                              11.24
# 00601                                              13.70
# 00601                                               7.66
# 00602                                              12.41
# ...                                                  ...
# 99925                                              15.79
# 99926                                              13.21
# 99927                                              14.58
# 99928                                              16.10
# 99929                                              13.89
#
#        Estimated percent of all people age 55-64, between 2014-2018.  \
# zip
# 00501                                              13.01
# 00601                                              11.96
# 00601                                              13.65
# 00601                                               6.16
# 00602                                              17.61
# ...                                                  ...
# 99925                                              17.44
# 99926                                              12.97
# 99927                                              17.64
# 99928                                              16.46
# 99929                                              20.57
#
#        Estimated percent of all people 65 or older, between 2014-2018.  \
# zip
# 00501                                              10.54
# 00601                                              15.22
# 00601                                              18.96
# 00601                                              23.07
# 00602                                              21.15
# ...                                                  ...
# 99925                                              12.91
# 99926                                              12.78
# 99927                                              17.86
# 99928                                              15.76
# 99929                                              22.06
#
#        Estimated typical (median) age of all people between 2013-2017.
# zip
# 00501                                               38.0
# 00601                                               39.0
# 00601                                               39.0
# 00601                                               32.0
# 00602                                               47.0
# ...                                                  ...
# 99925                                               43.0
# 99926                                               33.0
# 99927                                               44.0
# 99928                                               44.0
# 99929                                               49.0
#
# [170781 rows x 10 columns]

# %% [markdown]
# ## For each index(Zip_1), we want the average of all the data belonging to this zipcode
#  - we do not want unrelated columns to be averaged so just drop them.

# %%
df = d2018.merge(age, how = 'left', left_on = 'tract', right_on = 'Census Tract').dropna().set_index('zip').sort_index()

# %%
output = df.groupby(df.index).agg('mean').drop(['tract','FIPS Code', 'Formatted FIPS',],axis=1)

# %%
output.to_csv('Age_Output.csv')
